# %%
word_list = []
with open('words_alpha.txt') as file:
    word_list = file.read().split()


answer = 'ALL THE VARIETY, ALL THE CHARM, ALL THE BEAUTY OF LIFE IS MADE UP OF LIGHT AND SHADOW. THE DAY THAT HAD BEEN CLEAR AND BRIGHT BEGAN TO CLOUD OVER; DROPS OF RAIN BEGAN TO FALL. ONE BY ONE, THOSE AROUND SOUGHT SHELTER, BUT THERE WAS A KIND OF QUIET AND PEACE IN THE SUDDEN CHANGE. THERE IS SOMETHING CALMING IN THE ACCEPTANCE OF WHAT COMES, A RESIGNATION TO THE UNEXPECTED, THAT FILLS THE HEART WITH A NEW KIND OF AWARENESS. THE MIND, TOO, LIKE THE WORLD OUTSIDE, SHIFTS AND CHANGES, ADAPTING TO THE NEW WEATHER OF THOUGHTS AND FEELINGS. IT IS IN THESE MOMENTS OF TRANSFORMATION THAT ONE FEELS MOST ALIVE, MOST AWARE OF THE DEPTHS AND MYSTERIES WITHIN.'.replace('.','').replace(',','').replace('!','').replace('?','').replace(';','').lower().split()

print([word for word in answer if not word in word_list])
print('began' in word_list)
print(len('bb69ac60ca2cdff95b8a64d48006a0fa7c277af39fdedb70f18e51bfce2172020547146dc57c180d82551816f6c996170fcaa70f1e62f914097a50debf0f559e'))
# Out:
# []
# True
# 128
